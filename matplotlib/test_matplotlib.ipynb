# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import scienceplots
import latex

# %%
import os
import matplotlib.dates as mdates
import matplotlib.ticker as mtick

# data
df = pd.DataFrame({
      'Run': np.random.randn(9)+range(1,10),
      'Swim': np.random.randn(9)+range(1,10),
      'Cycle': np.random.randn(9)+range(1,10),
      'Mixed': np.random.randn(9)+range(1,10)})

df
# Out:
#         Run      Swim     Cycle     Mixed
# 0  1.699934  0.272624  0.812431  1.924809
# 1  1.994104  0.898050  1.537422  0.867919
# 2  2.560585  3.263564  2.670100  3.712094
# 3  2.825581  1.557243  5.095856  3.858255
# 4  5.043670  4.093057  4.465513  7.288573
# 5  5.658167  4.124557  6.657559  5.127316
# 6  6.803571  7.240719  6.782803  6.577238
# 7  7.830785  6.038135  7.374939  8.709193
# 8  8.275592  7.618346  7.977659  8.755266

# %%
# plot size and configuration
fig,ax = plt.subplots(figsize = (20,7.5))

# lines
for activity in df.columns:
    plt.plot(df.index,df[activity],marker = '^',label = f'{activity}')

# format y-axis
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1,decimals = 0))

# add title and axis labels
plt.title('Exercise types (survey respondents, men aged 18 - 60)')
plt.ylabel('Proportion')
plt.xlabel('Survey date')

# misc - grid and legend
plt.grid(axis = 'both',alpha = 0.45)
plt.legend(loc = 'best',ncol = 1)

# results
plt.show()

# %%
# plot
fig,ax = plt.subplots(figsize = (20,7.5))

# informative title + subtitle
title = 'Mixed training is gaining in popularity over time'
subtitle = 'Men aged 18-60 are ditching running and cycling in favour of a mixed training regime'

# add title + subtitle to plot
plt.text(
    x = 0.125,y = 0.90,s = title,fontname = 'Arial',
    fontsize = 20,ha='left',transform = fig.transFigure
)
plt.text(
    x = 0.125,y = 0.86,s = subtitle,fontname = 'Arial',
    fontsize = 16,ha = 'left',transform = fig.transFigure
)

# lines
for activity in df.columns:
    plt.plot(df.index,df[activity],marker = '^',label = f'{activity}')

# format y-axis
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1,decimals = 0))

# axis labels
plt.ylabel('Proportion')
plt.xlabel('Survey date')

# misc - grid and legend
plt.grid(axis = 'both',alpha = 0.45)
plt.legend(loc = 'best',ncol = 1)

# fiddle with space above chart
plt.subplots_adjust(top=0.8, wspace=0.3)

plt.show()

# %%
# data
df = pd.DataFrame(
    {
        'Time':['Early morning','Morning','Midday','Afternoon','Evening'],
        'Athletes':[0.17,0.075,0.23,0.125,0.4]
    }
)

# %%
# plot
fig,ax = plt.subplots(figsize = (20,7.5))

# bars
plt.bar(df['Time'],df['Athletes'])

# format y-axis
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(1,decimals = 0))

# grid line
plt.grid(axis = 'y',alpha = 0.45)

# labels and title
plt.title('Proportion of athletes training, by time of day')
plt.ylabel('Proportion')
plt.xlabel('Time of day')

plt.show()

# %%
plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
})

# %%
# data
df = pd.DataFrame({
      'x_axis': range(1,10),
      'y_axis': np.random.randn(9)*80+range(1,10)
  })

# plot
plt.plot('x_axis', 'y_axis', data=df, linestyle='-', marker='o')
plt.show()

# %%
# data
df = pd.DataFrame({
      'x_axis': range(1,10),
      'y_axis': np.random.randn(9)*80+range(1,10)
  })

# plot
plt.style.use('science')
plt.plot('x_axis', 'y_axis', data=df, linestyle='-', marker='o')
plt.show()
